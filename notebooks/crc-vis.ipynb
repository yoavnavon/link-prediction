# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Timesplit (Same Day)

# %%
heuristic = pd.read_csv('results/timesplit_large_heuristic.csv')
node2vec = pd.read_csv('results/timesplit_large_node2vec.csv')
deepwalk = pd.read_csv('results/timesplit_large_deepwalk.csv')

# %%
heuristic.head(5)
# Out:
#      size model  precision  recall  roc_auc  accuracy  f1_score
# 0   99999   xgb     0.6104  0.3559   0.5644    0.5644    0.4496
# 1   99999    rf     0.6107  0.3563   0.5646    0.5646    0.4501
# 2  149999   xgb     0.6166  0.3832   0.5725    0.5725    0.4727
# 3  149999    rf     0.6146  0.3796   0.5708    0.5708    0.4693
# 4  200000   xgb     0.6396  0.4088   0.5892    0.5892    0.4988

# %%
fig, ax = plt.subplots(2, 4, sharex='col', figsize=(20, 5))
# Precision
ax[0][0].plot('size','precision', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][0].plot('size','precision', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][0].plot('size','precision', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][0].set_xlabel('N edges')
ax[0][0].set_title('XGB')
ax[0][1].plot('size','precision', data=heuristic[heuristic['model'] == 'rf'])
ax[0][1].plot('size','precision', data=node2vec[node2vec['model'] == 'rf'])
ax[0][1].plot('size','precision', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][1].set_xlabel('N edges')
ax[0][1].set_title('Random Forest')
ax[0][0].set_ylabel('Precision')
ax[0][0].legend(['traditional','node2vec','deepwalk'])

# Recall
ax[0][2].plot('size','recall', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][2].plot('size','recall', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][2].plot('size','recall', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][2].set_xlabel('N edges')
ax[0][2].set_title('XGB')
ax[0][3].plot('size','recall', data=heuristic[heuristic['model'] == 'rf'])
ax[0][3].plot('size','recall', data=node2vec[node2vec['model'] == 'rf'])
ax[0][3].plot('size','recall', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][3].set_xlabel('N edges')
ax[0][3].set_title('Random Forest')
ax[0][2].set_ylabel('Recall')

# ROC AUC
ax[1][0].plot('size','roc_auc', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][0].set_xlabel('N edges')
ax[1][1].plot('size','roc_auc', data=heuristic[heuristic['model'] == 'rf'])
ax[1][1].plot('size','roc_auc', data=node2vec[node2vec['model'] == 'rf'])
ax[1][1].plot('size','roc_auc', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][1].set_xlabel('N edges')
ax[1][0].set_ylabel('ROC AUC')

# F1 Score
ax[1][2].plot('size','f1_score', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][2].plot('size','f1_score', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][2].plot('size','f1_score', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][2].set_xlabel('N edges')
ax[1][3].plot('size','f1_score', data=heuristic[heuristic['model'] == 'rf'])
ax[1][3].plot('size','f1_score', data=node2vec[node2vec['model'] == 'rf'])
ax[1][3].plot('size','f1_score', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][3].set_xlabel('N edges')
ax[1][2].set_ylabel('F1 Score')
plt.show()

fig, ax = plt.subplots(1, 2, sharex='col', figsize=(20, 5))
ax[0].plot('size','accuracy', data=heuristic[heuristic['model'] == 'xgb'])
ax[0].plot('size','accuracy', data=node2vec[node2vec['model'] == 'xgb'])
ax[0].plot('size','accuracy', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0].set_xlabel('N edges')
ax[0].set_title('XGB')
ax[1].plot('size','accuracy', data=heuristic[heuristic['model'] == 'rf'])
ax[1].plot('size','accuracy', data=node2vec[node2vec['model'] == 'rf'])
ax[1].plot('size','accuracy', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1].set_xlabel('N edges')
ax[1].set_title('Random Forest')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['traditional','node2vec','deepwalk'])
plt.show()

# %% [markdown]
# ## 2. Timesplit (Same time diferent days)

# %%
heuristic = pd.read_csv('results/time_sampling_heuristic.csv')
node2vec = pd.read_csv('results/time_sampling_node2vec.csv')
deepwalk = pd.read_csv('results/time_sampling_deepwalk.csv')

# %%
heuristic.head(5)
# Out:
#      size model  precision  recall  roc_auc  accuracy  f1_score
# 0   49999   xgb     0.7707  0.8161   0.7866    0.7866    0.7927
# 1   49999    rf     0.7710  0.8179   0.7875    0.7875    0.7938
# 2   99998   xgb     0.7855  0.8337   0.8030    0.8030    0.8089
# 3   99998    rf     0.7857  0.8328   0.8028    0.8028    0.8085
# 4  149999   xgb     0.7738  0.8275   0.7928    0.7928    0.7998

# %%
fig, ax = plt.subplots(2, 4, sharex='col', figsize=(20, 5))
# Precision
ax[0][0].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][0].set_xlabel('N edges')
ax[0][0].set_title('XGB')
ax[0][1].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][1].set_xlabel('N edges')
ax[0][1].set_title('Random Forest')
ax[0][0].set_ylabel('Precision')
ax[0][0].legend(['traditional','node2vec','deepwalk'])

# Recall
ax[0][2].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][2].set_xlabel('N edges')
ax[0][2].set_title('XGB')
ax[0][3].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][3].set_xlabel('N edges')
ax[0][3].set_title('Random Forest')
ax[0][2].set_ylabel('Recall')

# ROC AUC
ax[1][0].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][0].set_xlabel('N edges')
ax[1][1].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][1].set_xlabel('N edges')
ax[1][0].set_ylabel('ROC AUC')

# F1 Score
ax[1][2].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][2].set_xlabel('N edges')
ax[1][3].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][3].set_xlabel('N edges')
ax[1][2].set_ylabel('F1 Score')
plt.show()

fig, ax = plt.subplots(1, 2, sharex='col', figsize=(20, 5))
ax[0].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0].set_xlabel('N edges')
ax[0].set_title('XGB')
ax[1].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1].set_xlabel('N edges')
ax[1].set_title('Random Forest')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['traditional','node2vec','deepwalk'])
plt.show()

# %% [markdown]
# ## 3. Random Samples

# %%
heuristic = pd.read_csv('results/random_sample_heuristic_.csv')
node2vec = pd.read_csv('results/random_sample_node2vec_.csv')
deepwalk = pd.read_csv('results/random_sample_deepwalk_.csv')

# %%
heuristic.head(5)
# Out:
#     size model  precision  recall  roc_auc  accuracy  f1_score
# 0  50000   xgb     0.7302  0.6161   0.6942    0.6942    0.6683
# 1  50000    rf     0.7302  0.6161   0.6942    0.6942    0.6683
# 2  74998   xgb     0.7203  0.6776   0.7072    0.7072    0.6983
# 3  74998    rf     0.7203  0.6776   0.7072    0.7072    0.6983
# 4  99996   xgb     0.7223  0.6723   0.7069    0.7069    0.6964

# %%
fig, ax = plt.subplots(2, 4, sharex='col', figsize=(20, 5))
# Precision
ax[0][0].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][0].set_xlabel('N edges')
ax[0][0].set_title('XGB')
ax[0][1].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][1].set_xlabel('N edges')
ax[0][1].set_title('Random Forest')
ax[0][0].set_ylabel('Precision')
ax[0][0].legend(['traditional','node2vec','deepwalk'])

# Recall
ax[0][2].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][2].set_xlabel('N edges')
ax[0][2].set_title('XGB')
ax[0][3].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][3].set_xlabel('N edges')
ax[0][3].set_title('Random Forest')
ax[0][2].set_ylabel('Recall')

# ROC AUC
ax[1][0].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][0].set_xlabel('N edges')
ax[1][1].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][1].set_xlabel('N edges')
ax[1][0].set_ylabel('ROC AUC')

# F1 Score
ax[1][2].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][2].set_xlabel('N edges')
ax[1][3].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][3].set_xlabel('N edges')
ax[1][2].set_ylabel('F1 Score')
plt.show()

fig, ax = plt.subplots(1, 2, sharex='col', figsize=(20, 5))
ax[0].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0].set_xlabel('N edges')
ax[0].set_title('XGB')
ax[1].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1].set_xlabel('N edges')
ax[1].set_title('Random Forest')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['traditional','node2vec','deepwalk'])
plt.show()

# %% [markdown]
# ## 4. Node Neighborhood Sampling

# %%
heuristic1 = pd.read_csv('results/node_sampling_combined_heuristic.csv')
node2vec1 = pd.read_csv('results/node_sampling_combined_node2vec.csv')
deepwalk1 = pd.read_csv('results/node_sampling_combined_deepwalk.csv')

heuristic2 = pd.read_csv('results2/node_sampling_large_heuristic.csv')
node2vec2 = pd.read_csv('results2/node_sampling_large_node2vec.csv')
deepwalk2 = pd.read_csv('results2/node_sampling_large_deepwalk.csv')

heuristic = pd.concat([heuristic1,heuristic2])
node2vec = pd.concat([node2vec1,node2vec2])
deepwalk = pd.concat([deepwalk1,deepwalk2])

# %%
heuristic
# Out:
#        size model  precision  recall  roc_auc  accuracy  f1_score
# 0     15555   xgb     0.8282  0.9903   0.8924    0.8924    0.9020
# 1     15555    rf     0.8289  0.9849   0.8908    0.8908    0.9002
# 2     95011   xgb     0.8079  0.9884   0.8767    0.8767    0.8891
# 3     95011    rf     0.8077  0.9861   0.8756    0.8756    0.8880
# 4    174526   xgb     0.8080  0.9790   0.8732    0.8732    0.8853
# 5    174526    rf     0.8081  0.9790   0.8732    0.8733    0.8854
# 6    256208   xgb     0.8096  0.9698   0.8709    0.8709    0.8825
# 7    256208    rf     0.8096  0.9695   0.8708    0.8708    0.8824
# 8    335332   xgb     0.8083  0.9641   0.8677    0.8677    0.8793
# 9    335332    rf     0.8080  0.9618   0.8666    0.8666    0.8782
# 10   415210   xgb     0.8101  0.9562   0.8661    0.8661    0.8771
# 11   415210    rf     0.8101  0.9562   0.8660    0.8660    0.8771
# 0    535149   xgb     0.8035  0.9475   0.8579    0.8579    0.8696
# ...

# %%
fig, ax = plt.subplots(2, 4, sharex='col', figsize=(20, 5))
# Precision
ax[0][0].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][0].set_xlabel('N edges')
ax[0][0].set_title('XGB')
ax[0][1].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][1].set_xlabel('N edges')
ax[0][1].set_title('Random Forest')
ax[0][0].set_ylabel('Precision')
ax[0][0].legend(['traditional','node2vec','deepwalk'])

# Recall
ax[0][2].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][2].set_xlabel('N edges')
ax[0][2].set_title('XGB')
ax[0][3].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][3].set_xlabel('N edges')
ax[0][3].set_title('Random Forest')
ax[0][2].set_ylabel('Recall')

# ROC AUC
ax[1][0].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][0].set_xlabel('N edges')
ax[1][1].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][1].set_xlabel('N edges')
ax[1][0].set_ylabel('ROC AUC')

# F1 Score
ax[1][2].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][2].set_xlabel('N edges')
ax[1][3].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][3].set_xlabel('N edges')
ax[1][2].set_ylabel('F1 Score')
plt.show()

fig, ax = plt.subplots(1, 2, sharex='col', figsize=(20, 5))
ax[0].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0].set_xlabel('N edges')
ax[0].set_title('XGB')
ax[1].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1].set_xlabel('N edges')
ax[1].set_title('Random Forest')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['traditional','node2vec','deepwalk'])
plt.show()

# %% [markdown]
# ## 6. BFS Sampling

# %%
heuristic = pd.read_csv('results2/bfs_sampling_heuristic.csv')
node2vec = pd.read_csv('results2/bfs_sampling_node2vec.csv')
deepwalk = pd.read_csv('results2/bfs_sampling_deepwalk.csv')

# %%
heuristic.head(5)
# Out:
#     size model  precision  recall  roc_auc  accuracy  f1_score
# 0  25279   xgb     0.6823  0.5154   0.6377    0.6377    0.5872
# 1  25279    rf     0.6834  0.5092   0.6366    0.6366    0.5836
# 2  50772   xgb     0.6779  0.5358   0.6406    0.6406    0.5985
# 3  50772    rf     0.6783  0.5274   0.6386    0.6386    0.5934
# 4  76397   xgb     0.6803  0.5288   0.6402    0.6402    0.5951

# %%
fig, ax = plt.subplots(2, 4, sharex='col', figsize=(20, 5))
# Precision
ax[0][0].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][0].set_xlabel('N edges')
ax[0][0].set_title('XGB')
ax[0][1].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][1].set_xlabel('N edges')
ax[0][1].set_title('Random Forest')
ax[0][0].set_ylabel('Precision')
ax[0][0].legend(['traditional','node2vec','deepwalk'])

# Recall
ax[0][2].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][2].set_xlabel('N edges')
ax[0][2].set_title('XGB')
ax[0][3].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][3].set_xlabel('N edges')
ax[0][3].set_title('Random Forest')
ax[0][2].set_ylabel('Recall')

# ROC AUC
ax[1][0].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][0].set_xlabel('N edges')
ax[1][1].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][1].set_xlabel('N edges')
ax[1][0].set_ylabel('ROC AUC')

# F1 Score
ax[1][2].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][2].set_xlabel('N edges')
ax[1][3].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][3].set_xlabel('N edges')
ax[1][2].set_ylabel('F1 Score')
plt.show()

fig, ax = plt.subplots(1, 2, sharex='col', figsize=(20, 5))
ax[0].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0].set_xlabel('N edges')
ax[0].set_title('XGB')
ax[1].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1].set_xlabel('N edges')
ax[1].set_title('Random Forest')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['traditional','node2vec','deepwalk'])
plt.show()

# %% [markdown]
# ## 7. Random WCC

# %%
heuristic = pd.read_csv('results/random_wcc_sampling_heuristic.csv')
node2vec = pd.read_csv('results/random_wcc_sampling_node2vec.csv')
deepwalk = pd.read_csv('results/random_wcc_sampling_deepwalk.csv')

# %%
heuristic.head(5)
# Out:
#     size model  precision  recall  roc_auc  accuracy  f1_score
# 0  18822   xgb     0.9673  0.9610   0.9643    0.9643    0.9642
# 1  18822    rf     0.9732  0.9416   0.9578    0.9578    0.9571
# 2  30928   xgb     0.9736  0.9644   0.9691    0.9691    0.9690
# 3  30928    rf     0.9736  0.9620   0.9679    0.9679    0.9677
# 4  41945   xgb     0.9734  0.9366   0.9555    0.9555    0.9546

# %%
fig, ax = plt.subplots(2, 4, sharex='col', figsize=(20, 5))
# Precision
ax[0][0].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][0].set_xlabel('N edges')
ax[0][0].set_title('XGB')
ax[0][1].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][1].set_xlabel('N edges')
ax[0][1].set_title('Random Forest')
ax[0][0].set_ylabel('Precision')
ax[0][0].legend(['traditional','node2vec','deepwalk'])

# Recall
ax[0][2].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][2].set_xlabel('N edges')
ax[0][2].set_title('XGB')
ax[0][3].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][3].set_xlabel('N edges')
ax[0][3].set_title('Random Forest')
ax[0][2].set_ylabel('Recall')

# ROC AUC
ax[1][0].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][0].set_xlabel('N edges')
ax[1][1].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][1].set_xlabel('N edges')
ax[1][0].set_ylabel('ROC AUC')

# F1 Score
ax[1][2].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][2].set_xlabel('N edges')
ax[1][3].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][3].set_xlabel('N edges')
ax[1][2].set_ylabel('F1 Score')
plt.show()

fig, ax = plt.subplots(1, 2, sharex='col', figsize=(20, 5))
ax[0].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0].set_xlabel('N edges')
ax[0].set_title('XGB')
ax[1].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1].set_xlabel('N edges')
ax[1].set_title('Random Forest')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['traditional','node2vec','deepwalk'])
plt.show()

# %% [markdown]
# ## 8. Node (In & Out) Sampling

# %%
heuristic = pd.read_csv('results/node_inout_sampling_heuristic.csv')
node2vec = pd.read_csv('results/node_inout_sampling_node2vec.csv')
deepwalk = pd.read_csv('results/node_inout_sampling_deepwalk.csv')

# %%
heuristic.head(5)
# Out:
#     size model  precision  recall  roc_auc  accuracy  f1_score
# 0  14420   xgb     0.7016  0.5888   0.6692    0.6692    0.6403
# 1  14420    rf     0.7020  0.5828   0.6677    0.6677    0.6368
# 2  27689   xgb     0.6849  0.5823   0.6571    0.6571    0.6294
# 3  27689    rf     0.6844  0.5804   0.6564    0.6564    0.6282
# 4  40863   xgb     0.6889  0.5684   0.6558    0.6558    0.6229

# %%
fig, ax = plt.subplots(2, 4, sharex='col', figsize=(20, 5))
# Precision
ax[0][0].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][0].set_xlabel('N edges')
ax[0][0].set_title('XGB')
ax[0][1].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][1].set_xlabel('N edges')
ax[0][1].set_title('Random Forest')
ax[0][0].set_ylabel('Precision')
ax[0][0].legend(['traditional','node2vec','deepwalk'])

# Recall
ax[0][2].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][2].set_xlabel('N edges')
ax[0][2].set_title('XGB')
ax[0][3].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][3].set_xlabel('N edges')
ax[0][3].set_title('Random Forest')
ax[0][2].set_ylabel('Recall')

# ROC AUC
ax[1][0].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][0].set_xlabel('N edges')
ax[1][1].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][1].set_xlabel('N edges')
ax[1][0].set_ylabel('ROC AUC')

# F1 Score
ax[1][2].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][2].set_xlabel('N edges')
ax[1][3].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][3].set_xlabel('N edges')
ax[1][2].set_ylabel('F1 Score')
plt.show()

fig, ax = plt.subplots(1, 2, sharex='col', figsize=(20, 5))
ax[0].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0].set_xlabel('N edges')
ax[0].set_title('XGB')
ax[1].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1].set_xlabel('N edges')
ax[1].set_title('Random Forest')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['traditional','node2vec','deepwalk'])
plt.show()

# %% [markdown]
# ## X. DEBUG

# %%
heuristic = pd.read_csv('results/time_sampling_heuristic.csv')
node2vec = pd.read_csv('results/time_sampling_node2vec.csv')
deepwalk = pd.read_csv('results/time_sampling_deepwalk.csv')

# %%
heuristic.head(5)
# Out:
#      size model  precision  recall  roc_auc  accuracy  f1_score
# 0   49999   xgb     0.7707  0.8161   0.7866    0.7866    0.7927
# 1   49999    rf     0.7710  0.8179   0.7875    0.7875    0.7938
# 2   99998   xgb     0.7855  0.8337   0.8030    0.8030    0.8089
# 3   99998    rf     0.7857  0.8328   0.8028    0.8028    0.8085
# 4  149999   xgb     0.7738  0.8275   0.7928    0.7928    0.7998

# %%
fig, ax = plt.subplots(2, 4, sharex='col', figsize=(20, 5))
# Precision
ax[0][0].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][0].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][0].set_xlabel('N edges')
ax[0][0].set_title('XGB')
ax[0][1].plot('size','precision','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][1].plot('size','precision','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][1].set_xlabel('N edges')
ax[0][1].set_title('Random Forest')
ax[0][0].set_ylabel('Precision')
ax[0][0].legend(['traditional','node2vec','deepwalk'])

# Recall
ax[0][2].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0][2].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0][2].set_xlabel('N edges')
ax[0][2].set_title('XGB')
ax[0][3].plot('size','recall','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[0][3].plot('size','recall','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[0][3].set_xlabel('N edges')
ax[0][3].set_title('Random Forest')
ax[0][2].set_ylabel('Recall')

# ROC AUC
ax[1][0].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][0].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][0].set_xlabel('N edges')
ax[1][1].plot('size','roc_auc','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][1].plot('size','roc_auc','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][1].set_xlabel('N edges')
ax[1][0].set_ylabel('ROC AUC')

# F1 Score
ax[1][2].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[1][2].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[1][2].set_xlabel('N edges')
ax[1][3].plot('size','f1_score','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1][3].plot('size','f1_score','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1][3].set_xlabel('N edges')
ax[1][2].set_ylabel('F1 Score')
plt.show()

fig, ax = plt.subplots(1, 2, sharex='col', figsize=(20, 5))
ax[0].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'xgb'])
ax[0].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'xgb'])
ax[0].set_xlabel('N edges')
ax[0].set_title('XGB')
ax[1].plot('size','accuracy','-o', data=heuristic[heuristic['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=node2vec[node2vec['model'] == 'rf'])
ax[1].plot('size','accuracy','-o', data=deepwalk[deepwalk['model'] == 'rf'])
ax[1].set_xlabel('N edges')
ax[1].set_title('Random Forest')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['traditional','node2vec','deepwalk'])
plt.show()
